# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df["job_posted_date"] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample()
# Out:
#       job_title_short          job_title job_location          job_via  \
# 81856  Data Scientist  Sr Data Scientist      Alabama  via Recruit.net
#
#       job_schedule_type  job_work_from_home         search_location  \
# 81856         Full-time               False  Florida, United States
#
#           job_posted_date  job_no_degree_mention  job_health_insurance  \
# 81856 2023-07-20 00:05:53                  False                 False
#
#          job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 81856  United States        None              NaN              NaN
#
#          company_name                       job_skills  \
# 81856  Public Storage  ['sql', 'github', 'confluence']
#
#                                          job_type_skills
# 81856  {'async': ['confluence'], 'other': ['github'],...

# %%
df.sample(10)
# Out:
#              job_title_short                             job_title  \
# 98752          Data Engineer                         Data Engineer
# 88016         Data Scientist              Data Scientist - R (H/F)
# 423898     Software Engineer     Senior Software Engineer in Cloud
# 328290          Data Analyst  Human Resources - Audit Data Analyst
# 525917          Data Analyst        Business Intelligence Engineer
# 248685      Business Analyst              Sales Analyst Supervisor
# 458617  Senior Data Engineer                  Senior Data Engineer
# 358242         Data Engineer    Data platform engineer remote work
# 97163         Data Scientist  Data Scientist - Various seniorities
# 336795      Business Analyst                        Market Analyst
#
#                                        job_location               job_via  \
# 98752                                Manchester, UK       via Recruit.net
# 88016                               Lannion, France          via Sercanto
# 423898      San José Province, San José, Costa Rica  via BeBee Costa Rica
# 328290                                Princeton, NJ       via SimplyHired
# 525917                       Amsterdam, Netherlands         via Roku Jobs
# 248685            Taguig, Metro Manila, Philippines            via Indeed
# 458617                       Neuchâtel, Switzerland        via Jobscout24
# 358242  Natal, State of Rio Grande do Norte, Brazil          via Sercanto
# 97163                                         Italy         via Adzuna.it
# 336795                              Gainesville, FL             via BeBee
#
#        job_schedule_type  job_work_from_home          search_location  \
# 98752          Full-time               False           United Kingdom
# 88016          Full-time               False                   France
# 423898         Full-time               False               Costa Rica
# 328290         Temp work               False  New York, United States
# 525917         Full-time               False              Netherlands
# 248685         Full-time               False              Philippines
# 458617         Full-time               False              Switzerland
# 358242         Full-time               False                   Brazil
# 97163          Full-time               False                    Italy
# 336795         Full-time               False   Florida, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 98752  2023-02-12 00:18:19                   True                 False
# 88016  2023-09-30 00:29:29                  False                 False
# 423898 2023-12-28 17:28:32                  False                 False
# 328290 2023-10-24 23:00:16                  False                  True
# 525917 2023-06-21 11:25:34                  False                 False
# 248685 2023-07-07 07:22:24                  False                 False
# 458617 2023-01-31 15:25:11                  False                 False
# 358242 2023-10-20 23:35:21                   True                 False
# 97163  2023-01-09 00:07:43                  False                 False
# 336795 2023-10-13 23:02:21                  False                 False
#
#            job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 98752   United Kingdom        None              NaN              NaN
# 88016           France        None              NaN              NaN
# 423898      Costa Rica        None              NaN              NaN
# 328290   United States        None              NaN              NaN
# 525917     Netherlands        None              NaN              NaN
# 248685     Philippines        None              NaN              NaN
# 458617     Switzerland        None              NaN              NaN
# 358242          Brazil        None              NaN              NaN
# 97163            Italy        None              NaN              NaN
# 336795   United States        None              NaN              NaN
#
#                               company_name  \
# 98752   SUMMER-BROWNING ASSOCIATES LIMITED
# 88016                              Cooperl
# 423898                          Wind River
# 328290       Spectraforce Technologies Inc
# 525917                                Roku
# 248685      Monroe Consulting Phils., Inc.
# 458617                           Meanquest
# 358242                   Jobzem (50244745)
# 97163                           Spectus.ai
# 336795               Virtual Vocations Inc
#
#                                                job_skills  \
# 98752                                           ['azure']
# 88016                                               ['r']
# 423898  ['go', 'javascript', 'typescript', 'html', 'cs...
# 328290                    ['word', 'excel', 'powerpoint']
# 525917  ['sql', 'python', 'redshift', 'airflow', 'djan...
# 248685                                               None
# 458617  ['sql', 'python', 'nosql', 'sql server', 'azur...
# 358242                                          ['nosql']
# 97163   ['go', 'sql', 'python', 'html', 'jupyter', 'pa...
# 336795                                          ['excel']
#
#                                           job_type_skills
# 98752                                {'cloud': ['azure']}
# 88016                              {'programming': ['r']}
# 423898  {'async': ['jira'], 'other': ['docker', 'kuber...
# 328290  {'analyst_tools': ['word', 'excel', 'powerpoin...
# 525917  {'analyst_tools': ['looker'], 'cloud': ['redsh...
# 248685                                               None
# 458617  {'analyst_tools': ['tableau', 'cognos'], 'clou...
# 358242                         {'programming': ['nosql']}
# 97163   {'libraries': ['jupyter', 'pandas', 'numpy', '...
# 336795                       {'analyst_tools': ['excel']}

# %%
df.sample(10, random_state=42) # for same results
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# 780907              Data Engineer with Fivetran,Qlik Must
#
#                      job_location                 job_via job_schedule_type  \
# 502901                St Paul, MN               via BeBee         Full-time
# 406337                 London, UK            via LinkedIn         Full-time
# 659951    Newcastle upon Tyne, UK              via Indeed         Full-time
# 541593                      Malta         via Trabajo.org         Full-time
# 425158     Amsterdam, Netherlands          via NBC4i Jobs         Full-time
# 183426                  Singapore  via Singapore | JobsDB         Full-time
# 287790                  Tampa, FL            via LinkedIn         Full-time
# 541983              Chantilly, VA      via Clearance Jobs         Full-time
# 416896                     France            via LinkedIn         Full-time
# 780907  Mexico City, CDMX, Mexico        via BeBee México         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
# 183426               False               Singapore 2023-11-09 16:07:57
# 287790               False  Florida, United States 2023-07-14 17:02:23
# 541983               False                 Georgia 2023-06-15 19:44:34
# 416896               False                  France 2023-09-22 16:47:24
# 780907               False                  Mexico 2023-01-16 06:19:09
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
# 183426                  False                 False       Singapore
# 287790                   True                 False   United States
# 541983                  False                 False   United States
# 416896                  False                 False          France
# 780907                  False                 False          Mexico
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901        None              NaN              NaN           ManpowerGroup
# 406337        None              NaN              NaN                 Harnham
# 659951        None              NaN              NaN             Morgan King
# 541593        None              NaN              NaN                 Konnekt
# 425158        None              NaN              NaN  Independent Recruiters
# 183426        None              NaN              NaN    FLEXOSENSE PTE. LTD.
# 287790        None              NaN              NaN      Iris Software Inc.
# 541983        None              NaN              NaN                    SAIC
# 416896        None              NaN              NaN             KPMG France
# 780907        None              NaN              NaN        CORUS Consulting
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                               None
# 541593                                           ['jira']
# 425158                                         ['python']
# 183426  ['r', 'python', 'java', 'sql', 'sql server', '...
# 287790                         ['sql', 'hadoop', 'excel']
# 541983  ['sql', 'r', 'matlab', 'python', 'oracle', 'aw...
# 416896                                               None
# 780907  ['oracle', 'snowflake', 'aws', 'azure', 'alter...
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                               None
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}
# 183426  {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 287790  {'analyst_tools': ['excel'], 'libraries': ['ha...
# 541983  {'analyst_tools': ['power bi', 'tableau', 'qli...
# 416896                                               None
# 780907  {'analyst_tools': ['alteryx'], 'cloud': ['orac...

# %% [markdown]
# copy() method

# %%
import pandas as pd
dataset = load_dataset("lukebarousse/data_jobs")
df_original = dataset["train"].to_pandas

# %%
df_altered = df_original.copy()

# %%
df_altered.loc[0 : 5, "salary_year_avg"]

# %%
id(df_original)
# Out:
# 1559924657856

# %%
id(df_altered)
# Out:
# 1559924657856
